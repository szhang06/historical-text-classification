# %%
# as you can see current ram is 12GB only, to increase it run below code
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-74a19cf4343c> in <module>()
# ----> 1 w# as you can see current ram is 12GB only, to increase it run below code
#
# NameError: name 'w' is not defined

# %%
# i = []
# while True:
#   i.append(i)

# %%
# wait for few minutes, after that you will get a prompt that your notebook got crashed, do you want to increase ram ?

# %%
# in the prompt click - yes

# %%
# as you see the ram increase from 12GB to 25GB

# %%
#thanks for watching, keep learning

# %% [markdown]
# **NOTE**: PLease allow your browser to allow show pop-ups by sites as show below

# %%
#step-1

# %%
#step-2

# %%
from google.colab import drive

drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/historical_datasets/"

# %%
import csv
import os
import glob
import pandas as pd
text_files = glob.glob(path + "/**/*.txt", recursive = True)
print(text_files)
print(len(text_files))
# Out:
# ['/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_8.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_31.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_15.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_38.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_13.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_33.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_19.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_34.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_14.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_22.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_6.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_23.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_18.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_28.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_24.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_27.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_29.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_32.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_1.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_17.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_3.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_20.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_10.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_4.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_5.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_21.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_26.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_37.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_11.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_36.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_16.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_35.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_2.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_7.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_12.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_25.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_9.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_30.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_40.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_54.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_50.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_39.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_46.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_55.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_51.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_41.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_44.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_42.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_49.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_48.txt', '/content/drive/MyDrive/historical_datasets/lampeter_tracts/lampeter_53.txt', '/content/drive/MyDrive/histor ...
# 1065

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(input = "filename",  decode_error='ignore', stop_words="english")
X = vectorizer.fit_transform(text_files)
print(vectorizer.get_feature_names_out())
print(X.shape)
# Out:
# ['00' '000' '0000' ... 'ωe' 'ωf' 'ωx']
# (1065, 209799)

# %%
import numpy as np
labels = ["tract"]*120 + ["narrative_fiction"] * 128 + ["bible"] * 649 + ["treatise"] * 54 + ["drama"] * 74 + ["letter"]*13 + ["narrative_non_fiction"]*27

# %%
print(y.shape)
# Out:
# (1065,)

# %%
y = np.array(labels)

# %%
# from sklearn.utils import shuffle
# import numpy as np
# X, y = shuffle(X, y)

# %%
from sklearn.model_selection import train_test_split
# from sklearn.feature_extraction.text import CountVectorizer
# from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
mnb = MultinomialNB().fit(X_train, y_train)

# %%
mnb_predictions = mnb.predict(X_test)

# %%
# accuracy on X_test
accuracy = mnb.score(X_test, y_test)
print(accuracy)
# Out:
# 0.7699530516431925

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, mnb_predictions))
# Out:
#                        precision    recall  f1-score   support
#
#                 bible       0.84      1.00      0.91       144
#                 drama       0.00      0.00      0.00        19
#                letter       0.00      0.00      0.00         2
#     narrative_fiction       0.44      0.93      0.60        15
# narrative_non_fiction       0.00      0.00      0.00         4
#                 tract       0.62      0.22      0.32        23
#              treatise       1.00      0.17      0.29         6
#
#              accuracy                           0.77       213
#             macro avg       0.41      0.33      0.30       213
#          weighted avg       0.69      0.77      0.70       213
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# linearsvc
from sklearn.svm import LinearSVC
lsvc = LinearSVC().fit(X_train, y_train)
lsvc_predictions = lsvc.predict(X_test)
accuracy = lsvc.score(X_test, y_test)
print(accuracy)
# Out:
# 0.9765258215962441

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, lsvc_predictions))
# Out:
#                        precision    recall  f1-score   support
#
#                 bible       1.00      0.99      1.00       144
#                 drama       0.95      0.95      0.95        19
#                letter       1.00      0.50      0.67         2
#     narrative_fiction       0.83      1.00      0.91        15
# narrative_non_fiction       1.00      0.75      0.86         4
#                 tract       0.96      1.00      0.98        23
#              treatise       1.00      0.83      0.91         6
#
#              accuracy                           0.98       213
#             macro avg       0.96      0.86      0.89       213
#          weighted avg       0.98      0.98      0.98       213
